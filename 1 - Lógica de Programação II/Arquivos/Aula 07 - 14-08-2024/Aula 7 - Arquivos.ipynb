# %% [markdown]
# # Aula 7 - Arquivos
#
# Trabalhar com arquivos é uma parte fundamental da programação em Python, permitindo a leitura de dados de arquivos, escrita e manipulação no sistema de arquivos de várias maneiras.
#
# Aqui estão os conceitos básicos e algumas operações comuns ao lidar com arquivos em Python.

# %% [markdown]
# ## Manipulando arquivos

# %% [markdown]
# ### Abrindo Arquivos
# Para trabalhar com um arquivo em Python, precisamos abri-lo usando a função embutida open(). Esta função retorna um objeto de arquivo, que oferece métodos e atributos para interagir com o arquivo.

# %%
f = open("exemplo.txt", "r")
f
# Out:
# <_io.TextIOWrapper name='exemplo.txt' mode='r' encoding='cp1252'>

# %% [markdown]
# **Modos de Abertura de Arquivo**
#
# - 'r': Leitura (padrão). Erro se o arquivo não existir.
# - 'w': Escrita. Cria um novo arquivo ou sobrescreve o existente.
# - 'x': Criação exclusiva. Falha se o arquivo já existir.
# - 'a': Anexação. Adiciona ao final do arquivo se ele existir.
# - 'b': Modo binário.
# - 't': Modo de texto (padrão).
# - '+': Atualização (leitura e escrita).

# %% [markdown]
# ### Leitura
#
# - read(size): Lê uma quantidade de dados e retorna como strings (texto) ou bytes (binário).
# - readline(): Lê uma única linha do arquivo.
# - readlines(): Lê todas as linhas do arquivo como uma lista.

# %%
conteudo = f.read()
conteudo
# Out:
# 'Beatriz de M. Porto\n19:00\nBoa noite!\nAlex Buracosky\n19:00\nboa noitee\nMelissa Yung\n19:00\nBoa noitee\nBeatriz de M. Porto\n19:00\nFrio demais\nJosÃ© Cruz\n19:03\nÃ‰ o marcelo aÃ\xad\nAlessandra Cruz\n19:06\nBoa noite, pessoal!\nBacana, Beatriz e Eduardo!\nVocÃª\n19:09\ndef descrever(**kwargs):\n    print(kwargs)\n    for chave, valor in kwargs.items():\n        print(f"chave: {chave}, valor: {valor}")\n\ndescrever(nome="Joey", idade="8", especie="cachorro")\nBeatriz de M. Porto\n19:09\nhttps://pythontutor.com/\n\nEsse Ã© excelente tambÃ©m, pessoal.\nAlessandra Cruz\n19:10\nNao curto muito, Beatriz. Nao sei se quando tentei usar, eu nao soube....rs\nO que Ã© bem provÃ¡vel.\nVytor Siebra\n19:10\nprofessor, boa noite\nVou precisar sair 5 min agora\ncolocar o lixo pra fora :V\nAlessandra Cruz\n19:11\nAmo o Vim rs\nBeatriz de M. Porto\n19:12\nAinda bem que existem vÃ¡rios sites e possibilidades legais, nÃ©? Assim, conseguimos ir tentando. Alessandra, uma coisa desse que mandei que nÃ£o gosto Ã© o tema branco, que cansa o olho. Pelo menos no VSCode hÃ¡ o modo escuro!\nAlessandra Cruz\n19:12\nMas eu vou nele, Beatriz! Quero aprender a usar!\nBeatriz de M. Porto\n19:13\nEspero que te ajude!\nAlessandra Cruz\n19:13\nSe nao ajudar, eu te grito! :)\nNara GuimarÃ£es\n19:13\nLauro, desliguei a camera aqui so para arrumar o ambiente\nBeatriz de M. Porto\n19:13\nPor favor, estou sempre disponÃ\xadvel! :D\nDiogo Moura\n19:13\ntreta nao tem fim\nMauro Veloso\n19:14\nvdd kkk\'\nAlessandra Cruz\n19:14\nahhh...muito obrigada, Beatriz!\nBeatriz de M. Porto\n19:15\nImagina!\nVocÃª\n19:19\nApache spark\nScala\nJosÃ© Cruz\n19:21\nPorta de entrada de python Ã© top\nVocÃª\n19:22\ngo to\nJosÃ© Cruz\n19:25\nkkkkkkkkkkkk\nVytor Siebra\n19:25\nkkkkkkkkkkk\nTatiane Pereira\n19:25\nquem sabe faz ao vivo\nVytor Siebra\n19:25\ninteragindo na aula\nBeatriz de M. Porto\n19:25\nPOO live action\nJosÃ© Cruz\n19:25\nnao fala em morder\nVytor Siebra\n19:25\nKKKKKKK\nEsaac de Tillesse Monte\n19:26\nIoT em outro nÃ\xadvel aÃ\xad\nJosÃ© Cruz\n19:28\nwebscraping\nLucas Nobre Barbosa\n19:29\nA maioria das bibliotecas de dados usam POO.\n\nQuando vocÃª entende o que o mÃ©todo estÃ¡ fazendo por baixo dos panos, o nÃ\xadvel de compreensÃ£o da biblioteca aumenta exponencialmente.\nBeatriz de M. Porto\n19:29\nQue legal, Lucas. NÃ£o sabia.\nTatiane Pereira\n19:39\nnao\nLucas Nobre Barbosa\n19:40\nDeixa kkkkk\nFalo depois\nMauro Veloso\n19:40\nnao\nta ruim msm\nJosÃ© Cruz\n19:40\ntendi nada\nkkkkkkkkkkkkkkkkkk\nKauÃ£ CecÃ\xadlio\n19:53\nVou buscar uma Ã¡gua, jÃ¡ volto\nBeatriz de M. Porto\n19:53\nEu tbm\nVytor Siebra\n19:53\nvou precisar ficar ausente aqui rapidinho, volto no mÃ¡ximo em 5-10 min\nThiago Silva\n20:06\nBoa noite, estava no trabalho, desculpe o atraso\nJosÃ© Cruz\n20:09\nseparar as responsabilidades\nJosÃ© Cruz\n20:10\npython Ã© paz e amor\nTatiane Pereira\n20:11\nlivre arbÃ\xadtrio\nBeatriz de M. Porto\n20:11\nkkkkk\nRubens Sousa\n20:11\nkkkk\nDiana Osorio\n20:12\nVou sÃ³ fechar a porta por causa do barulho aqui, e jÃ¡ volto\nDiogo Moura\n20:12\nseja eternamente responsÃ¡vel pelo que fazes\nJosÃ© Cruz\n20:12\nJÃ¡ volto, vou fechar a camera rapidinho.\nvoltei\nJosÃ© Cruz\n20:16\ncallable\nDiogo Moura\n20:20\nquando comeÃ§a a aninha minha cabeÃ§a comeÃ§a a fica quente O.o\nBeatriz de M. Porto\n20:21\nNossa, sim. rs\nEsaac de Tillesse Monte\n20:21\nRealmente, enriquece a capacidade de abstraÃ§Ã£o kkkkk\nBeatriz de M. Porto\n20:21\nO debugador Ã© essencial nessas horas kkkk\nNara GuimarÃ£es\n20:22\ncoloquei o print(dobrar) para visualizar melhor\nNara GuimarÃ£es\n20:25\ndef criar_somador(n):\n    def somador(x):\n        return n + x\n    return somador\n\nsomar = criar_somador(20)\n\nprint(somar)\n\nsomar(10)\nMarcelo Oliveira\n20:25\ndef criar_somador(n):\n  def somar(x):\n    return n + x\n  return somar\nAlessandra Cruz\n20:26\nTranquilo nem sempre Ã©, mas tÃ´ entendendo e Ã© possÃ\xadvel buscar o conhecimento tambÃ©m.\nRubens Sousa\n20:26\ndef criar_somado ...

# %%
f.close()

# %%
f = open("exemplo.txt", "r")
f.readline().strip()
# Out:
# 'Beatriz de M. Porto'

# %%
f.close()

# %%
f = open("exemplo.txt", "r")
linhas = f.readlines()

for linha in linhas:
    print(linha.strip())
# Out:
# Beatriz de M. Porto
# 19:00
# Boa noite!
# Alex Buracosky
# 19:00
# boa noitee
# Melissa Yung
# 19:00
# Boa noitee
# Beatriz de M. Porto
# 19:00
# Frio demais
# JosÃ© Cruz
# 19:03
# Ã‰ o marcelo aÃ­
# Alessandra Cruz
# 19:06
# Boa noite, pessoal!
# Bacana, Beatriz e Eduardo!
# VocÃª
# 19:09
# def descrever(**kwargs):
# print(kwargs)
# for chave, valor in kwargs.items():
# print(f"chave: {chave}, valor: {valor}")
#
# descrever(nome="Joey", idade="8", especie="cachorro")
# Beatriz de M. Porto
# 19:09
# https://pythontutor.com/
#
# Esse Ã© excelente tambÃ©m, pessoal.
# Alessandra Cruz
# 19:10
# Nao curto muito, Beatriz. Nao sei se quando tentei usar, eu nao soube....rs
# O que Ã© bem provÃ¡vel.
# Vytor Siebra
# 19:10
# professor, boa noite
# Vou precisar sair 5 min agora
# colocar o lixo pra fora :V
# Alessandra Cruz
# 19:11
# Amo o Vim rs
# Beatriz de M. Porto
# 19:12
# Ainda bem que existem vÃ¡rios sites e possibilidades legais, nÃ©? Assim, conseguimos ir tentando. Alessandra, uma coisa desse que mandei que nÃ£o gosto Ã© o tema branco, que cansa o olho. Pelo menos no VSCode hÃ¡ o modo escuro!
# Alessandra Cruz
# 19:12
# Mas eu vou nele, Beatriz! Quero aprender a usar!
# Beatriz de M. Porto
# 19:13
# Espero que te ajude!
# Alessandra Cruz
# 19:13
# Se nao ajudar, eu te grito! :)
# Nara GuimarÃ£es
# 19:13
# Lauro, desliguei a camera aqui so para arrumar o ambiente
# Beatriz de M. Porto
# 19:13
# Por favor, estou sempre disponÃ­vel! :D
# Diogo Moura
# 19:13
# treta nao tem fim
# Mauro Veloso
# 19:14
# vdd kkk'
# Alessandra Cruz
# 19:14
# ahhh...muito obrigada, Beatriz!
# Beatriz de M. Porto
# 19:15
# Imagina!
# VocÃª
# 19:19
# Apache spark
# Scala
# JosÃ© Cruz
# 19:21
# Porta de entrada de python Ã© top
# VocÃª
# 19:22
# go to
# JosÃ© Cruz
# 19:25
# kkkkkkkkkkkk
# Vytor Siebra
# 19:25
# kkkkkkkkkkk
# Tatiane Pereira
# 19:25
# quem sabe faz ao vivo
# Vytor Siebra
# 19:25
# interagindo na aula
# Beatriz de M. Porto
# 19:25
# POO live action
# JosÃ© Cruz
# 19:25
# nao fala em morder
# Vytor Siebra
# 19:25
# KKKKKKK
# Esaac de Tillesse Monte
# 19:26
# IoT em outro nÃ­vel aÃ­
# JosÃ© Cruz
# 19:28
# webscraping
# Lucas Nobre Barbosa
# 19:29
# A maioria das bibliotecas de dados usam POO.
#
# Quando vocÃª entende o que o mÃ©todo estÃ¡ fazendo por baixo dos panos, o nÃ­vel de compreensÃ£o da biblioteca aumenta exponencialmente.
# Beatriz de M. Porto
# 19:29
# Que legal, Lucas. NÃ£o sabia.
# Tatiane Pereira
# 19:39
# nao
# Lucas Nobre Barbosa
# 19:40
# Deixa kkkkk
# Falo depois
# Mauro Veloso
# 19:40
# nao
# ta ruim msm
# JosÃ© Cruz
# 19:40
# tendi nada
# kkkkkkkkkkkkkkkkkk
# KauÃ£ CecÃ­lio
# 19:53
# Vou buscar uma Ã¡gua, jÃ¡ volto
# Beatriz de M. Porto
# 19:53
# Eu tbm
# Vytor Siebra
# 19:53
# vou precisar ficar ausente aqui rapidinho, volto no mÃ¡ximo em 5-10 min
# Thiago Silva
# 20:06
# Boa noite, estava no trabalho, desculpe o atraso
# JosÃ© Cruz
# 20:09
# separar as responsabilidades
# JosÃ© Cruz
# 20:10
# python Ã© paz e amor
# Tatiane Pereira
# 20:11
# livre arbÃ­trio
# Beatriz de M. Porto
# 20:11
# kkkkk
# Rubens Sousa
# 20:11
# kkkk
# Diana Osorio
# 20:12
# Vou sÃ³ fechar a porta por causa do barulho aqui, e jÃ¡ volto
# Diogo Moura
# 20:12
# seja eternamente responsÃ¡vel pelo que fazes
# JosÃ© Cruz
# 20:12
# JÃ¡ volto, vou fechar a camera rapidinho.
# voltei
# JosÃ© Cruz
# 20:16
# callable
# Diogo Moura
# 20:20
# quando comeÃ§a a aninha minha cabeÃ§a comeÃ§a a fica quente O.o
# Beatriz de M. Porto
# 20:21
# Nossa, sim. rs
# Esaac de Tillesse Monte
# 20:21
# Realmente, enriquece a capacidade de abstraÃ§Ã£o kkkkk
# Beatriz de M. Porto
# 20:21
# O debugador Ã© essencial nessas horas kkkk
# Nara GuimarÃ£es
# 20:22
# coloquei o print(dobrar) para visualizar melhor
# Nara GuimarÃ£es
# 20:25
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(20)
#
# print(somar)
#
# somar(10)
# Marcelo Oliveira
# 20:25
# def criar_somador(n):
# def somar(x):
# return n + x
# return somar
# Alessandra Cruz
# 20:26
# Tranquilo nem sempre Ã©, mas tÃ´ entendendo e Ã© possÃ­vel buscar o conhecimento tambÃ©m.
# Rubens Sousa
# 20:26
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(2)
#
# somar(10)
# Diana Osorio
# 20:26
# def criar_somador(n):
# def somador(x):
# return n+x
# return somador
#
# somar = criar_somador(2)
# somar(10)
# Esaac de Tillesse Monte
# 20:26
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(5)
# print(somar(15))
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(5)
# print(somar(15))
#
# Diana Osorio
# 20:26
# def criar_somador(n):
# def somador(x):
# return n+x
# return somador
#
# somar = criar_somador(2)
# somar(10)
# Esaac de Tillesse Monte
# 20:26
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(5)
# print(somar(15))
# def criar_somador(n):
# def somador(x):
# return n + x
# return somador
#
# somar = criar_somador(5)
# print(somar(15))
# VocÃª
# 20:27
# wrapper
# JosÃ© Cruz
# 20:29
# show
# Mauro Veloso
# 20:29
# blz
# VocÃª
# 20:31
# voltamos 8:45
# Nossa pessoal, por algum motivo meu nariz nÃ£o para de coÃ§ar kkkk
# Diana Osorio
# 20:33
# professor, minha internet caiu aqui, por isso cai
# VocÃª
# 20:34
# sem problemas
# Renan Moreira
# 20:45
# professor, uso o cllr como webcam mas ele descarregou, vou ter q ficar um tempo com a camera desligada atÃ© ele pegar uma carga, pode ser?
# KauÃ£ CecÃ­lio
# 20:45
# to terminando de comer aqui, ja abro a camera
# Rubens Sousa
# 20:49
# Professor, vou ficar com a cÃ¢mera fechado, pq estou comendo ainda
# Diogo Moura
# 20:52
# O.o o.O o.O
# Lucas Nobre Barbosa
# 20:53
# 3
# Nara GuimarÃ£es
# 20:53
# 54
# Nara GuimarÃ£es
# 20:56
# def criar_multiplicador(n):
# def multiplicador(x):
# def somador(m):
# return (x * n) + m
# return somador
# return multiplicador
#
# criar_multiplicador(3)(5)(2)
# Nara GuimarÃ£es
# 21:00
# minha_funcao = criar_multiplicador(3)
#
# clausura = minha_funcao.__closure__
#
# valor_de_n = clausura[0].cell_contents
# print(valor_de_n)
# assim da certo
# Mauro Veloso
# 21:07
# kiwi
# JosÃ© Cruz
# 21:08
# kkkkk
# Beatriz de M. Porto
# 21:09
# Eu ia pedir isso kkkk
# Nara GuimarÃ£es
# 21:13
# lista = [{5: 'banana'}, {2: 'maca'}, {3: 'durian'}, {4: 'abacate'}]
#
# lista.sort(key=lambda x: list(x.values())[0])
#
# print(lista)
# assim da certo Lauro
# JosÃ© Cruz
# 21:13
# tem que extrair os valores com items nÃ£o?
# Tatiane Pereira
# 21:22
# filter
# list(filter)
# JosÃ© Cruz
# 21:24
# blz
# Vytor Siebra
# 21:27
# eu kkk
# JosÃ© Cruz
# 21:27
# kkkkkk
# Mauro Veloso
# 21:27
# kkkk'
# Nara GuimarÃ£es
# 21:27
# voce consegue
# Diogo Moura
# 21:27
# nao consigo viver sem picanha
# XD
# Beatriz de M. Porto
# 21:27
# Sou hÃ¡ mais de dez anos ^^
# Vytor Siebra
# 21:28
# sou vegetariano hÃ¡ 2 anos
# Alessandra Cruz
# 21:28
# quando eu ficar rica.
# Beatriz de M. Porto
# 21:28
# Depende do pÃ£o, Lauro hahah
# Vytor Siebra
# 21:28
# massa Beatriz ^^
# Diogo Moura
# 21:28
# braba
# Mauro Veloso
# 21:29
# essa analogia ficou muito boa
# Nara GuimarÃ£es
# 21:29
# boa analogia
# Vytor Siebra
# 21:29
# mt boa
# JosÃ© Cruz
# 21:29
# Vou ser obrigado a comer um pao com ovo agora
# Beatriz de M. Porto
# 21:30
# kkkkkk
# Diogo Moura
# 21:30
# 2
# Diana Osorio
# 21:30
# segunda Ã© sempre tenso mesmo
# Alessandra Cruz
# 21:30
# Top, Beatriz. Para virar vegetariana, meu metabolismo precisa suplementar muito coisa.
# JosÃ© Cruz
# 21:30
# polegadas nÃ©
# Alessandra Cruz
# 21:31
# Hoje tÃ¡ 18 graus, professor.
# Aqui no Rio
# Diogo Moura
# 21:31
# LoL
# aqui na minha cidade 18 graus e considerado estado de calamidade
# JosÃ© Cruz
# 21:32
# Queria em diogo, ando de moto aqui no frio Ã© dificil kkkk
# Diogo Moura
# 21:34
# show
# JosÃ© Cruz
# 21:34
# tranquilo
# Ã© o gerador esse map nÃ©?
# JosÃ© Cruz
# 21:35
# otimizado, muito inteligente
# Diogo Moura
# 21:38
# nao pode continuar
# Renan Moreira
# 21:38
# vamo terminar
# Lucas Nobre Barbosa
# 21:38
# Pode continuar
# Rubens Sousa
# 21:38
# Bora terminar
# Nara GuimarÃ£es
# 21:40
# por conta da questao de funcao geradora
# JosÃ© Cruz
# 21:41
# pq ele jÃ¡ passou por todo o loop e nÃ£o tem "next"
# JosÃ© Cruz
# 21:46
# beleza
# ana carolina gomes
# 21:50
# no print
# Beatriz de M. Porto
# 21:52
# Eu jÃ¡ teria desistido xD
# Mauro Veloso
# 21:56
# EgÃ­dio
# JosÃ© Cruz
# 22:00
# kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Vytor Siebra
# 22:00
# tbm
# Beatriz de M. Porto
# 22:00
# O desespero bateu xD
# Lucas Nobre Barbosa
# 22:01
# NÃ£o usa comentÃ¡rios do tipo
#
# # Somando a e b
# soma = a + b
#
# kkkkkkk
# LÃ­via Minucelli
# 22:02
# Ã© bem isso mesmo
# kkk
# JosÃ© Cruz
# 22:02
# Ã© isso ai
# LÃ­via Minucelli
# 22:02
# depois que aprende o bÃ¡sico muito bem a curva de aprendizado diminui bastante
# JosÃ© Cruz
# 22:03
# tem muitos ferramenteiros no mercado
# Diogo Moura
# 22:04
# so sei que nada sei nem sei como passei
# Beatriz de M. Porto
# 22:04
# kkkkkkkkkkk
# Renan Moreira
# 22:04
# KKKKKKKKKKKKKKKKKKKKKKKKKK
# coe po
# Mauro Veloso
# 22:04
# kkkk'
# JosÃ© Cruz
# 22:05
# Bora montar um time de counterstrike pq o python aqui tÃ¡ embaÃ§ado kkkkkk
# Bora renan
# Beatriz de M. Porto
# 22:05
# kkkkkkkkkkkkkkkk
# Alessandra Cruz
# 22:05
# Boa noite pessoal! Obrigada, Lauro!
# Diana Osorio
# 22:05
# obrigada pessoal! boa noite!!!
# Nara GuimarÃ£es
# 22:06
# boa noite pessoal
# Bruna AraÃºjo
# 22:06
# Boa noite!
# Vytor Siebra
# 22:06
# boa noite pessoal
# Beatriz de M. Porto
# 22:06
# Boa noite, pessoal! Obrigadaaa, Lauroo
# Vytor Siebra
# 22:06
# atÃ© a proxima
# Thiago Silva
# 22:06
# boa noite galera
# KauÃ£ CecÃ­lio
# 22:06
# boa noite
# JosÃ© Cruz
# 22:06
# valeu boa noite! :)
# Marcelo Oliveira
# 22:06
# Boa noite pessoal !
# Renan Moreira
# 22:06
# vlw pessoal, boa noite

# %%
f.close()

# %% [markdown]
# ### Escrita
#
# Para escrever em um arquivo, podemos abrir modo de escrita ('w', 'a' etc.) e usar o método write() ou writelines().

# %%
f = open("exemplo.txt", "a")
f.write("\nTeste de escrita 5")
f.close()

# %% [markdown]
# ### Fechar
#
# É importante fechar um arquivo quando terminamos de usá-lo, para liberar recursos do sistema. Isso pode ser feito com o método close().

# %%
f.close()

# %% [markdown]
# ### Usando with - gerenciador de contexto
#
# Para garantir que os arquivos sejam sempre fechados corretamente, é uma boa prática usar o bloco with, que automaticamente cuida de fechar o arquivo.

# %%
with open("exemplo.txt", "r") as f:
    conteudo = f.read()
    print(conteudo)
# Out:
# Beatriz de M. Porto
# 19:00
# Boa noite!
# Alex Buracosky
# 19:00
# boa noitee
# Melissa Yung
# 19:00
# Boa noitee
# Beatriz de M. Porto
# 19:00
# Frio demais
# JosÃ© Cruz
# 19:03
# Ã‰ o marcelo aÃ­
# Alessandra Cruz
# 19:06
# Boa noite, pessoal!
# Bacana, Beatriz e Eduardo!
# VocÃª
# 19:09
# def descrever(**kwargs):
#     print(kwargs)
#     for chave, valor in kwargs.items():
#         print(f"chave: {chave}, valor: {valor}")
#
# descrever(nome="Joey", idade="8", especie="cachorro")
# Beatriz de M. Porto
# 19:09
# https://pythontutor.com/
#
# Esse Ã© excelente tambÃ©m, pessoal.
# Alessandra Cruz
# 19:10
# Nao curto muito, Beatriz. Nao sei se quando tentei usar, eu nao soube....rs
# O que Ã© bem provÃ¡vel.
# Vytor Siebra
# 19:10
# professor, boa noite
# Vou precisar sair 5 min agora
# colocar o lixo pra fora :V
# Alessandra Cruz
# 19:11
# Amo o Vim rs
# Beatriz de M. Porto
# 19:12
# Ainda bem que existem vÃ¡rios sites e possibilidades legais, nÃ©? Assim, conseguimos ir tentando. Alessandra, uma coisa desse que mandei que nÃ£o gosto Ã© o tema branco, que cansa o olho. Pelo menos no VSCode hÃ¡ o modo escuro!
# Alessandra Cruz
# 19:12
# Mas eu vou nele, Beatriz! Quero aprender a usar!
# Beatriz de M. Porto
# 19:13
# Espero que te ajude!
# Alessandra Cruz
# 19:13
# Se nao ajudar, eu te grito! :)
# Nara GuimarÃ£es
# 19:13
# Lauro, desliguei a camera aqui so para arrumar o ambiente
# Beatriz de M. Porto
# 19:13
# Por favor, estou sempre disponÃ­vel! :D
# Diogo Moura
# 19:13
# treta nao tem fim
# Mauro Veloso
# 19:14
# vdd kkk'
# Alessandra Cruz
# 19:14
# ahhh...muito obrigada, Beatriz!
# Beatriz de M. Porto
# 19:15
# Imagina!
# VocÃª
# 19:19
# Apache spark
# Scala
# JosÃ© Cruz
# 19:21
# Porta de entrada de python Ã© top
# VocÃª
# 19:22
# go to
# JosÃ© Cruz
# 19:25
# kkkkkkkkkkkk
# Vytor Siebra
# 19:25
# kkkkkkkkkkk
# Tatiane Pereira
# 19:25
# quem sabe faz ao vivo
# Vytor Siebra
# 19:25
# interagindo na aula
# Beatriz de M. Porto
# 19:25
# POO live action
# JosÃ© Cruz
# 19:25
# nao fala em morder
# Vytor Siebra
# 19:25
# KKKKKKK
# Esaac de Tillesse Monte
# 19:26
# IoT em outro nÃ­vel aÃ­
# JosÃ© Cruz
# 19:28
# webscraping
# Lucas Nobre Barbosa
# 19:29
# A maioria das bibliotecas de dados usam POO.
#
# Quando vocÃª entende o que o mÃ©todo estÃ¡ fazendo por baixo dos panos, o nÃ­vel de compreensÃ£o da biblioteca aumenta exponencialmente.
# Beatriz de M. Porto
# 19:29
# Que legal, Lucas. NÃ£o sabia.
# Tatiane Pereira
# 19:39
# nao
# Lucas Nobre Barbosa
# 19:40
# Deixa kkkkk
# Falo depois
# Mauro Veloso
# 19:40
# nao
# ta ruim msm
# JosÃ© Cruz
# 19:40
# tendi nada
# kkkkkkkkkkkkkkkkkk
# KauÃ£ CecÃ­lio
# 19:53
# Vou buscar uma Ã¡gua, jÃ¡ volto
# Beatriz de M. Porto
# 19:53
# Eu tbm
# Vytor Siebra
# 19:53
# vou precisar ficar ausente aqui rapidinho, volto no mÃ¡ximo em 5-10 min
# Thiago Silva
# 20:06
# Boa noite, estava no trabalho, desculpe o atraso
# JosÃ© Cruz
# 20:09
# separar as responsabilidades
# JosÃ© Cruz
# 20:10
# python Ã© paz e amor
# Tatiane Pereira
# 20:11
# livre arbÃ­trio
# Beatriz de M. Porto
# 20:11
# kkkkk
# Rubens Sousa
# 20:11
# kkkk
# Diana Osorio
# 20:12
# Vou sÃ³ fechar a porta por causa do barulho aqui, e jÃ¡ volto
# Diogo Moura
# 20:12
# seja eternamente responsÃ¡vel pelo que fazes
# JosÃ© Cruz
# 20:12
# JÃ¡ volto, vou fechar a camera rapidinho.
# voltei
# JosÃ© Cruz
# 20:16
# callable
# Diogo Moura
# 20:20
# quando comeÃ§a a aninha minha cabeÃ§a comeÃ§a a fica quente O.o
# Beatriz de M. Porto
# 20:21
# Nossa, sim. rs
# Esaac de Tillesse Monte
# 20:21
# Realmente, enriquece a capacidade de abstraÃ§Ã£o kkkkk
# Beatriz de M. Porto
# 20:21
# O debugador Ã© essencial nessas horas kkkk
# Nara GuimarÃ£es
# 20:22
# coloquei o print(dobrar) para visualizar melhor
# Nara GuimarÃ£es
# 20:25
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(20)
#
# print(somar)
#
# somar(10)
# Marcelo Oliveira
# 20:25
# def criar_somador(n):
#   def somar(x):
#     return n + x
#   return somar
# Alessandra Cruz
# 20:26
# Tranquilo nem sempre Ã©, mas tÃ´ entendendo e Ã© possÃ­vel buscar o conhecimento tambÃ©m.
# Rubens Sousa
# 20:26
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(2)
#
# somar(10)
# Diana Osorio
# 20:26
# def criar_somador(n):
#     def somador(x):
#         return n+x
#     return somador
#
# somar = criar_somador(2)
# somar(10)
# Esaac de Tillesse Monte
# 20:26
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(5)
# print(somar(15))
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(5)
# print(somar(15))
#
# Diana Osorio
# 20:26
# def criar_somador(n):
#     def somador(x):
#         return n+x
#     return somador
#
# somar = criar_somador(2)
# somar(10)
# Esaac de Tillesse Monte
# 20:26
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(5)
# print(somar(15))
# def criar_somador(n):
#     def somador(x):
#         return n + x
#     return somador
#
# somar = criar_somador(5)
# print(somar(15))
# VocÃª
# 20:27
# wrapper
# JosÃ© Cruz
# 20:29
# show
# Mauro Veloso
# 20:29
# blz
# VocÃª
# 20:31
# voltamos 8:45
# Nossa pessoal, por algum motivo meu nariz nÃ£o para de coÃ§ar kkkk
# Diana Osorio
# 20:33
# professor, minha internet caiu aqui, por isso cai
# VocÃª
# 20:34
# sem problemas
# Renan Moreira
# 20:45
# professor, uso o cllr como webcam mas ele descarregou, vou ter q ficar um tempo com a camera desligada atÃ© ele pegar uma carga, pode ser?
# KauÃ£ CecÃ­lio
# 20:45
# to terminando de comer aqui, ja abro a camera
# Rubens Sousa
# 20:49
# Professor, vou ficar com a cÃ¢mera fechado, pq estou comendo ainda
# Diogo Moura
# 20:52
# O.o o.O o.O
# Lucas Nobre Barbosa
# 20:53
# 3
# Nara GuimarÃ£es
# 20:53
# 54
# Nara GuimarÃ£es
# 20:56
# def criar_multiplicador(n):
#     def multiplicador(x):
#         def somador(m):
#             return (x * n) + m
#         return somador
#     return multiplicador
#
# criar_multiplicador(3)(5)(2)
# Nara GuimarÃ£es
# 21:00
# minha_funcao = criar_multiplicador(3)
#
# clausura = minha_funcao.__closure__
#
# valor_de_n = clausura[0].cell_contents
# print(valor_de_n)
# assim da certo
# Mauro Veloso
# 21:07
# kiwi
# JosÃ© Cruz
# 21:08
# kkkkk
# Beatriz de M. Porto
# 21:09
# Eu ia pedir isso kkkk
# Nara GuimarÃ£es
# 21:13
# lista = [{5: 'banana'}, {2: 'maca'}, {3: 'durian'}, {4: 'abacate'}]
#
# lista.sort(key=lambda x: list(x.values())[0])
#
# print(lista)
# assim da certo Lauro
# JosÃ© Cruz
# 21:13
# tem que extrair os valores com items nÃ£o?
# Tatiane Pereira
# 21:22
# filter
# list(filter)
# JosÃ© Cruz
# 21:24
# blz
# Vytor Siebra
# 21:27
# eu kkk
# JosÃ© Cruz
# 21:27
# kkkkkk
# Mauro Veloso
# 21:27
# kkkk'
# Nara GuimarÃ£es
# 21:27
# voce consegue
# Diogo Moura
# 21:27
# nao consigo viver sem picanha
# XD
# Beatriz de M. Porto
# 21:27
# Sou hÃ¡ mais de dez anos ^^
# Vytor Siebra
# 21:28
# sou vegetariano hÃ¡ 2 anos
# Alessandra Cruz
# 21:28
# quando eu ficar rica.
# Beatriz de M. Porto
# 21:28
# Depende do pÃ£o, Lauro hahah
# Vytor Siebra
# 21:28
# massa Beatriz ^^
# Diogo Moura
# 21:28
# braba
# Mauro Veloso
# 21:29
# essa analogia ficou muito boa
# Nara GuimarÃ£es
# 21:29
# boa analogia
# Vytor Siebra
# 21:29
# mt boa
# JosÃ© Cruz
# 21:29
# Vou ser obrigado a comer um pao com ovo agora
# Beatriz de M. Porto
# 21:30
# kkkkkk
# Diogo Moura
# 21:30
# 2
# Diana Osorio
# 21:30
# segunda Ã© sempre tenso mesmo
# Alessandra Cruz
# 21:30
# Top, Beatriz. Para virar vegetariana, meu metabolismo precisa suplementar muito coisa.
# JosÃ© Cruz
# 21:30
# polegadas nÃ©
# Alessandra Cruz
# 21:31
# Hoje tÃ¡ 18 graus, professor.
# Aqui no Rio
# Diogo Moura
# 21:31
# LoL
# aqui na minha cidade 18 graus e considerado estado de calamidade
# JosÃ© Cruz
# 21:32
# Queria em diogo, ando de moto aqui no frio Ã© dificil kkkk
# Diogo Moura
# 21:34
# show
# JosÃ© Cruz
# 21:34
# tranquilo
# Ã© o gerador esse map nÃ©?
# JosÃ© Cruz
# 21:35
# otimizado, muito inteligente
# Diogo Moura
# 21:38
# nao pode continuar
# Renan Moreira
# 21:38
# vamo terminar
# Lucas Nobre Barbosa
# 21:38
# Pode continuar
# Rubens Sousa
# 21:38
# Bora terminar
# Nara GuimarÃ£es
# 21:40
# por conta da questao de funcao geradora
# JosÃ© Cruz
# 21:41
# pq ele jÃ¡ passou por todo o loop e nÃ£o tem "next"
# JosÃ© Cruz
# 21:46
# beleza
# ana carolina gomes
# 21:50
# no print
# Beatriz de M. Porto
# 21:52
# Eu jÃ¡ teria desistido xD
# Mauro Veloso
# 21:56
# EgÃ­dio
# JosÃ© Cruz
# 22:00
# kkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkkk
# Vytor Siebra
# 22:00
# tbm
# Beatriz de M. Porto
# 22:00
# O desespero bateu xD
# Lucas Nobre Barbosa
# 22:01
# NÃ£o usa comentÃ¡rios do tipo
#
# # Somando a e b
# soma = a + b
#
# kkkkkkk
# LÃ­via Minucelli
# 22:02
# Ã© bem isso mesmo
# kkk
# JosÃ© Cruz
# 22:02
# Ã© isso ai
# LÃ­via Minucelli
# 22:02
# depois que aprende o bÃ¡sico muito bem a curva de aprendizado diminui bastante
# JosÃ© Cruz
# 22:03
# tem muitos ferramenteiros no mercado
# Diogo Moura
# 22:04
# so sei que nada sei nem sei como passei
# Beatriz de M. Porto
# 22:04
# kkkkkkkkkkk
# Renan Moreira
# 22:04
# KKKKKKKKKKKKKKKKKKKKKKKKKK
# coe po
# Mauro Veloso
# 22:04
# kkkk'
# JosÃ© Cruz
# 22:05
# Bora montar um time de counterstrike pq o python aqui tÃ¡ embaÃ§ado kkkkkk
# Bora renan
# Beatriz de M. Porto
# 22:05
# kkkkkkkkkkkkkkkk
# Alessandra Cruz
# 22:05
# Boa noite pessoal! Obrigada, Lauro!
# Diana Osorio
# 22:05
# obrigada pessoal! boa noite!!!
# Nara GuimarÃ£es
# 22:06
# boa noite pessoal
# Bruna AraÃºjo
# 22:06
# Boa noite!
# Vytor Siebra
# 22:06
# boa noite pessoal
# Beatriz de M. Porto
# 22:06
# Boa noite, pessoal! Obrigadaaa, Lauroo
# Vytor Siebra
# 22:06
# atÃ© a proxima
# Thiago Silva
# 22:06
# boa noite galera
# KauÃ£ CecÃ­lio
# 22:06
# boa noite
# JosÃ© Cruz
# 22:06
# valeu boa noite! :)
# Marcelo Oliveira
# 22:06
# Boa noite pessoal !
# Renan Moreira
# 22:06
# vlw pessoal, boa noite
# Teste de escrita 5qwe

# %%
f.readline()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 f.readline()
#
# ValueError: I/O operation on closed file.

# %% [markdown]
# ### Manipulação de Arquivos e Diretórios
#
# Além de ler e escrever em arquivos, Python também permite manipular caminhos de arquivos e diretórios usando os módulos os e shutil. Podemos criar diretórios, listar arquivos em um diretório, mover, copiar e deletar arquivos e diretórios.

# %%
import os

for item in os.listdir("exemplo"):
    print(item)
# Out:
# arquivo1.csv

# %%
for item in os.listdir("."):
    print(item)
# Out:
# arquivo1.csv
# Aula 7 - Arquivos.ipynb
# exemplo
# exemplo.json
# exemplo.txt
# Materiais de Estudo.txt

# %% [markdown]
# ### Trabalhando com arquivos temporários
#
# Python oferece o módulo tempfile, que permite criar arquivos e diretórios temporários de forma segura e fácil. Esses arquivos temporários são úteis para quando você não quer ou não precisa persistir dados no disco rígido.

# %% [markdown]
# Eles são úteis para:
#
# - Armazenar dados que só são necessários durante a execução do programa.
# - Quando trabalhar com dados sensíveis que não devem persistir em disco após a execução.
# - Para evitar conflitos de nomeação em sistemas de arquivos ao gerar muitos arquivos intermediários.

# %%
import tempfile

with tempfile.TemporaryFile(mode="w+t") as temp_file:
    temp_file.write("Evite i/o na eng de dados\n")
    temp_file.write("Ola, sou um arquivo temporario")

    temp_file.seek(0)
    print(temp_file.read())
# Out:
# Evite i/o na eng de dados
# Ola, sou um arquivo temporario

# %% [markdown]
# ## Arquivos CSV
#
# Arquivos CSV (Comma-Separated Values, ou Valores Separados por Vírgula) são uma forma popular e simples de armazenar dados tabulares. Eles são amplamente utilizados para troca de dados entre diferentes aplicações, sistemas e plataformas.

# %% [markdown]
# #### Leitura

# %%
import csv

with open("arquivo1.csv", mode="r") as arquivo_csv:
    conteudo = csv.reader(arquivo_csv, delimiter=";")
    for l in conteudo:
        print(l)
# Out:
# ['Lauro', ' 28', ' RJ']
# ['Beatriz', ' 20', ' SP']
# ['Mauro', ' 20', ' 20']

# %% [markdown]
# ### Escrita

# %%
with open("output.csv", mode="w", newline="") as arquivo:
    aux = csv.writer(arquivo, delimiter=",", quotechar='"')

    aux.writerow(['Nome', 'Idade', 'Estado'])
    aux.writerow(['Lauro', ' 28', ' SP'])
    aux.writerow(['Beatriz', ' 24', ' SP'])
    aux.writerow(['Mauro', ' 24', ' MG'])

# %% [markdown]
# ### Se estivermos trabalhando com cabeçalhos:

# %%
dados = [
    {'Nome': 'Alessandra', 'Estado': 'RJ'},
    {'Nome': 'Vytor', 'Estado': 'PE'}
]

with open("saida.csv", mode="w", newline="") as arquivo:
    colunas = ["Nome", "Estado"]
    aux = csv.DictWriter(arquivo, fieldnames=colunas)

    aux.writeheader()
    for dado in dados:
        aux.writerow(dado)

# %%
with open("saida.csv", mode="r") as arquivo:
    aux = csv.DictReader(arquivo)
    for a in aux:
        print(a["Nome"], a["Estado"])
# Out:
# Alessandra RJ
# Vytor PE

# %% [markdown]
# ## Arquivos JSON
#
# Arquivos JSON (JavaScript Object Notation) são um formato padrão para troca de dados entre aplicações e são amplamente utilizados em programação, especialmente em APIs web e configurações.
#
# Python oferece o módulo json na biblioteca padrão para facilitar a leitura e a escrita de arquivos JSON.

# %% [markdown]
# ### Leitura

# %%
import json

with open("exemplo.json", "r") as arquivo:
    dados = json.load(arquivo)
    print(dados)

type(dados)
# Out:
# {'Idade': 28, 'Nome': 'Lauro'}
# dict

# %% [markdown]
# ### Escrita

# %%
import json
dados = {'Idade': 28, 'Nome': 'Lauro'}

with open("exemplo/output.json", "w") as arquivo:
    json.dump(dados, arquivo)

# %% [markdown]
# ### Formatação
#
# Para tornar o arquivo JSON mais legível, você pode usar os parâmetros indent e sort_keys em json.dump().

# %%
with open("exemplo/output.json", "w") as arquivo:
    json.dump(dados, arquivo, indent=4, sort_keys=True)

# %% [markdown]
# ### JSON e strings
#
# Além de ler e escrever em arquivos, você pode converter strings JSON para objetos Python com json.loads() e objetos Python para strings JSON com json.dumps().

# %% [markdown]
# ### JSON e dicionários
#
# - JSON para Dicionário: Quando você lemos dados JSON em Python, usando o módulo json, esses dados são convertidos em dicionários Python. Isso significa que podemoa trabalhar com dados JSON de forma nativa como se estivesse trabalhando com dicionários em Python.
#
# - Dicionário para JSON: Da mesma forma, quando temos um dicionário em Python e quer salvá-lo como um arquivo JSON ou transmiti-lo para uma API web, podemos converter esse dicionário em uma string JSON usando o módulo json.

# %% [markdown]
# ## Arquivos XML
#
# XML (eXtensible Markup Language) é uma linguagem de marcação que define um conjunto de regras para codificar documentos de forma legível tanto para humanos quanto para máquinas.
#
# A estrutura do XML é semelhante à do HTML, com a diferença de que as tags no XML são definidas pelo usuário, tornando-o altamente personalizável e adequado para a descrição de dados em uma ampla variedade de domínios.

# %% [markdown]
# - Estruturado: permite representar dados em uma estrutura hierárquica usando elementos e atributos.
# - Auto-descritivo: as tags personalizadas descrevem a natureza dos dados, tornando o documento auto-explicativo.
# - Extensível: podemos criar suas próprias tags para atender às necessidades específicas de seus dados.

# %% [markdown]
# ### Manipulando XML
#
# Python fornece várias bibliotecas para trabalhar com XML, como xml.etree.ElementTree, que é uma parte da biblioteca padrão e fornece funcionalidades para analisar e criar dados XML.

# %% [markdown]
# ## Parquet
#
# Parquet é um formato de arquivo colunar otimizado para o uso com sistemas de processamento de dados de Big Data, como Hadoop e Spark.
#
# Desenvolvido inicialmente pela Cloudera e Twitter, ele é projetado para ser altamente eficiente tanto em termos de armazenamento quanto de desempenho de leitura, especialmente para dados de análise complexa. O formato

# %% [markdown]
# **Uso em Engenharia de Dados**
#
# Em engenharia de dados, o formato Parquet é particularmente útil para:
#
# - Armazenar e processar grandes volumes de dados de forma eficiente.
# - Realizar análises e consultas complexas em grandes datasets.
# - Integrar dados com ecossistemas de Big Data, como plataformas de análise em nuvem e sistemas de processamento distribuído.
