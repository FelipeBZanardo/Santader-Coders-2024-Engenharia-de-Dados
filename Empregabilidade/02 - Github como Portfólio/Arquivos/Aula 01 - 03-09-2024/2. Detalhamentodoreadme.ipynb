# %% [markdown]
# ## GitHub para empregabilidade - Git/Github
#
# Na aula de hoje iremos explorar os seguintes tópicos:
#
# - Detalhamento do README

# %% [markdown]
# ## 1. Cabeçalho Principal
#
#  ```### Olá sou o **Daniel Vieira**```
#
# ### Olá sou o **Daniel Vieira**
#
# 1. Função: Apresenta o nome do proprietário do perfil de maneira amigável e pessoal.
#
# 2. Estilo: Uso de negrito para destacar o nome, tornando-o imediatamente visível.
#
# ## 2. Subtítulo com a Profissão
#
# ```### Especialista em Engenharia de Sistemas no Itaú Unbanco e Professor na Ada```
#
# ### Especialista em Engenharia de Sistemas no Itaú Unbanco e Professor na Ada
#
# 1. Função: Fornece informações sobre a ocupação profissional e o papel educacional do perfil.
#
# 2. Estilo: Utiliza um tamanho de fonte menor que o cabeçalho principal, mas ainda significativo para mostrar a relevância profissional.
#
#
# ## 3. Descrição Motivacional
#
# ```### *Compartilho ideias e padrões de projetos corporativos. Espero que este perfil possa te ajudar!*```
#
# ### *Compartilho ideias e padrões de projetos corporativos. Espero que este perfil possa te ajudar!*
#
# 1. Função: Estabelece o propósito do perfil, indicando que o usuário compartilha conhecimento e experiência.
#
# 2. Estilo: Uso de itálico para uma abordagem mais pessoal e direta.
#
# ## 4. Lista de Qualificações e Experiências
#
# - 👨‍💻 Specialist DevOpS Engineer
# - 🏦 Itaú Unibanco
# - 🏫 Ada
# - 📚 Técnologo em redes de Computadores - Fatec
# - 📃 Cerificações:
#     - AWS Solutions Architected Professional;
#     - ... (e outras certificações)
#
# 1. Função: Lista as posições profissionais, educação e certificações, destacando a expertise e a formação.
#
# 2. Estilo: Uso de emojis para adicionar um elemento visual e tornar a leitura mais agradável.
#
# ## 5. Ferramentas e Tecnologias
#
# ```<div>```
#
#       <img src="https://cdn.jsdelivr.net/gh/devicons/devicon/icons/github/github-original.svg" width="40" height="40"/>
#
#       <img src="https://cdn.jsdelivr.net/gh/devicons/devicon/icons/git/git-original.svg" width="40" height="40"/>
#
#       <img src="https://cdn.jsdelivr.net/gh/devicons/devicon/icons/java/java-original.svg" width="40" height="40"/>
#
#       <img src="https://cdn.jsdelivr.net/gh/devicons/devicon/icons/python/python-original.svg" width="40" height="40"/>
#
#       <img src="https://cdn.jsdelivr.net/gh/devicons/devicon/icons/linux/linux-original.svg" width="40" height="40"/>
#
# ```</div>```
#
# 1. Função: Mostra as ferramentas e tecnologias com as quais o usuário está familiarizado.
#
# 2. Estilo: Uso de ícones para representação visual das tecnologias, facilitando a identificação rápida.
#
# ## 6. Links para Redes Sociais e Contato
#
# ```<div align=""center""> ```
#
#      <a href="https://www.linkedin.com/in/daniel-vieira-9a9680127/">Linkedin</a>
# ```</div>```
#
# 1. Função: Fornece um meio direto de contato através do LinkedIn.
#
#
#
# ## 7. Estatísticas do GitHub
#
# [![Top Langs](https://github-readme-stats.vercel.app/api/top-langs/?username=danielgundim)](https://github.com/danielgundim/github-readme-stats)
#
# ![GitHub stats](https://github-readme-stats.vercel.app/api?username=danielgundim&show_icons=true)
#
# 1. Função: Exibe estatísticas do GitHub, como linguagens mais usadas e status do perfil.
# 2. Estilo: Uso de gráficos gerados automaticamente para fornecer uma visão rápida das atividades do usuário no GitHub.
#
# ## 8. Conclusão
#
# Este README é um modelo de como informações profissionais e pessoais podem ser combinadas para criar um perfil no GitHub que não apenas mostra habilidades técnicas, mas também apresenta a personalidade e os interesses do usuário. É um ótimo exemplo de como usar elementos visuais, como ícones e badges, junto com texto bem estruturado para criar um perfil atraente e informativo.
#
# ## 9. Documentação
#
# - https://www.markdownguide.org/
# - https://docs.github.com/pt/get-started/writing-on-github/getting-started-with-writing-and-formatting-on-github/basic-writing-and-formatting-syntax
